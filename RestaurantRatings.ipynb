# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("F:\Machine Learning Project\RestaurantRatings\RestaurantRatings\TA_restaurants_curated.csv")

# %%
df.describe()
# Out:
#           Unnamed: 0        Ranking         Rating  Number of Reviews
# count  125527.000000  115876.000000  115897.000000      108183.000000
# mean     3974.686131    3657.463979       3.987441         125.184983
# std      4057.687698    3706.255301       0.678814         310.833311
# min         0.000000       1.000000      -1.000000           2.000000
# 25%      1042.000000     965.000000       3.500000           9.000000
# 50%      2445.000000    2256.000000       4.000000          32.000000
# 75%      5626.000000    5237.000000       4.500000         114.000000
# max     18211.000000   16444.000000       5.000000       16478.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125527 entries, 0 to 125526
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         125527 non-null  int64
#  1   Name               125527 non-null  object
#  2   City               125527 non-null  object
#  3   Cuisine Style      94176 non-null   object
#  4   Ranking            115876 non-null  float64
#  5   Rating             115897 non-null  float64
#  6   Price Range        77672 non-null   object
#  7   Number of Reviews  108183 non-null  float64
#  8   Reviews            115911 non-null  object
#  9   URL_TA             125527 non-null  object
#  10  ID_TA              125527 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 10.5+ MB

# %%
df.head(5)
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
#                                              Reviews  \
# 0  [['Just like home', 'A Warm Welcome to Wintry ...
# 1  [['Great food and staff', 'just perfect'], ['0...
# 2  [['Satisfaction', 'Delicious old school restau...
# 3  [['True five star dinner', 'A superb evening o...
# 4  [['Best meal.... EVER', 'super food experience...
#
#                                               URL_TA      ID_TA
# 0  /Restaurant_Review-g188590-d11752080-Reviews-M...  d11752080
# 1  /Restaurant_Review-g188590-d693419-Reviews-De_...    d693419
# 2  /Restaurant_Review-g188590-d696959-Reviews-La_...    d696959
# 3  /Restaurant_Review-g188590-d1239229-Reviews-Vi...   d1239229
# 4  /Restaurant_Review-g188590-d6864170-Reviews-Li...   d6864170

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'City', 'Cuisine Style', 'Ranking', 'Rating',
#        'Price Range', 'Number of Reviews', 'Reviews', 'URL_TA', 'ID_TA'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
#                                              Reviews  \
# 0  [['Just like home', 'A Warm Welcome to Wintry ...
# 1  [['Great food and staff', 'just perfect'], ['0...
# 2  [['Satisfaction', 'Delicious old school restau...
# 3  [['True five star dinner', 'A superb evening o...
# 4  [['Best meal.... EVER', 'super food experience...
#
#                                               URL_TA      ID_TA
# 0  /Restaurant_Review-g188590-d11752080-Reviews-M...  d11752080
# 1  /Restaurant_Review-g188590-d693419-Reviews-De_...    d693419
# 2  /Restaurant_Review-g188590-d696959-Reviews-La_...    d696959
# 3  /Restaurant_Review-g188590-d1239229-Reviews-Vi...   d1239229
# 4  /Restaurant_Review-g188590-d6864170-Reviews-Li...   d6864170

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# Name                     0
# City                     0
# Cuisine Style        31351
# Ranking               9651
# Rating                9630
# Price Range          47855
# Number of Reviews    17344
# Reviews               9616
# URL_TA                   0
# ID_TA                    0
# dtype: int64

# %%
df = df.rename(columns={"Cuisine Style": "Cuisine_Style", "Price Range": "Price_Range","Unnamed: 0":"Restaurant_id"})

# %%
df.City.unique()
# Out:
# array(['Amsterdam', 'Athens', 'Barcelona', 'Berlin', 'Bratislava',
#        'Brussels', 'Budapest', 'Copenhagen', 'Dublin', 'Edinburgh',
#        'Geneva', 'Hamburg', 'Helsinki', 'Krakow', 'Lisbon', 'Ljubljana',
#        'London', 'Luxembourg', 'Lyon', 'Madrid', 'Milan', 'Munich',
#        'Oporto', 'Oslo', 'Paris', 'Prague', 'Rome', 'Stockholm', 'Vienna',
#        'Warsaw', 'Zurich'], dtype=object)

# %%
df.Price_Range.unique()
# Out:
# array(['$$ - $$$', '$$$$', '$', nan], dtype=object)

# %%
df.City.unique()
# Out:
# array(['Amsterdam', 'Athens', 'Barcelona', 'Berlin', 'Bratislava',
#        'Brussels', 'Budapest', 'Copenhagen', 'Dublin', 'Edinburgh',
#        'Geneva', 'Hamburg', 'Helsinki', 'Krakow', 'Lisbon', 'Ljubljana',
#        'London', 'Luxembourg', 'Lyon', 'Madrid', 'Milan', 'Munich',
#        'Oporto', 'Oslo', 'Paris', 'Prague', 'Rome', 'Stockholm', 'Vienna',
#        'Warsaw', 'Zurich'], dtype=object)

# %%
df.Price_Range.unique()
# Out:
# array(['$$ - $$$', '$$$$', '$', nan], dtype=object)

# %%
sns.set_style("white")

f, axarr = plt.subplots( )
plt.suptitle('Restaurant Review Metadata', fontsize=18)
f.subplots_adjust(hspace=0.5)

(df
     .groupby('ID_TA')
     .Rating
     .count()
     .sort_values(ascending=False)
     .reset_index(drop=True)
).plot.line()
axarr.set_title("Restaurants by Number of Reviews")

sns.despine()

# %%
#above plot suggest every restaurant has one review!

# %%
df.Cuisine_Style.unique()
# Out:
# array(["['French', 'Dutch', 'European']",
#        "['Dutch', 'European', 'Vegetarian Friendly', 'Gluten Free Options']",
#        "['Mediterranean', 'French', 'International', 'European', 'Vegetarian Friendly', 'Vegan Options']",
#        ..., "['Seafood', 'European', 'Croatian']",
#        "['French', 'American', 'International', 'European', 'Thai', 'Wine Bar', 'Scandinavian']",
#        "['Italian', 'French', 'Swiss', 'European', 'Spanish', 'Portuguese']"],
#       dtype=object)

# %%
df['Cuisine Style Was NAN'] = df['Cuisine_Style'].isna()
df['Cuisine_Style'] = df['Cuisine_Style'].fillna("['Unknown']")

# Could have used as 
df['Cuisine_Qtty'] = df['Cuisine_Style'].str[2:-2].str.split("', '")
df['Cuisine_Qtty'] = df['Cuisine_Qtty'].apply(lambda x: 0 if x is np.nan else len(x))

# %%
df.head(5)
# Out:
#    Restaurant_id                        Name       City  \
# 0              0  Martine of Martine's Table  Amsterdam
# 1              1         De Silveren Spiegel  Amsterdam
# 2              2                     La Rive  Amsterdam
# 3              3                    Vinkeles  Amsterdam
# 4              4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine_Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price_Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
#                                              Reviews  \
# 0  [['Just like home', 'A Warm Welcome to Wintry ...
# 1  [['Great food and staff', 'just perfect'], ['0...
# 2  [['Satisfaction', 'Delicious old school restau...
# 3  [['True five star dinner', 'A superb evening o...
# 4  [['Best meal.... EVER', 'super food experience...
#
#                                               URL_TA      ID_TA  \
# 0  /Restaurant_Review-g188590-d11752080-Reviews-M...  d11752080
# 1  /Restaurant_Review-g188590-d693419-Reviews-De_...    d693419
# 2  /Restaurant_Review-g188590-d696959-Reviews-La_...    d696959
# 3  /Restaurant_Review-g188590-d1239229-Reviews-Vi...   d1239229
# 4  /Restaurant_Review-g188590-d6864170-Reviews-Li...   d6864170
#
#    Cuisine Style Was NAN  Cuisine_Qtty
# 0                  False             3
# 1                  False             4
# 2                  False             6
# 3                  False             7
# 4                  False             6

# %%
df.Reviews.unique()
# Out:
# array(["[['Just like home', 'A Warm Welcome to Wintry Amsterdam'], ['01/03/2018', '01/01/2018']]",
#        "[['Great food and staff', 'just perfect'], ['01/06/2018', '01/04/2018']]",
#        "[['Satisfaction', 'Delicious old school restaurant'], ['01/04/2018', '01/04/2018']]",
#        ..., "[['Cordon Bleu'], ['10/02/2014']]",
#        '[["Don\'t waste your time, go somewhere else!", \'Horrible\'], [\'10/23/2016\', \'07/03/2015\']]',
#        "[['Poor quality, small portions, miserable st...'], ['09/04/2017']]"],
#       dtype=object)

# %%
df.Price_Range.unique()
# Out:
# array(['$$ - $$$', '$$$$', '$', nan], dtype=object)

# %%
price_range = {'$': 0, '$$ - $$$': 1, '$$$$': 2}

df['Pricing'] = df['Price_Range'].map(price_range)
df['Pricing'].fillna(df['Pricing'].mean(), inplace=True)

df['Price_Unknown'] = df['Price_Range'].isna().astype('int32')

# %%
del df['Price_Range']

# %%
f, axarr = plt.subplots(2,2 ,figsize=(10, 7))
plt.suptitle('Restaurant No. of Cuisines', fontsize=18)
f.subplots_adjust(hspace=0.5)

sns.countplot(df.Pricing.dropna().astype(int),ax=axarr[0][0])
sns.countplot(df.Price_Unknown.dropna().astype(int),ax=axarr[0][1])
sns.countplot(df.Cuisine_Qtty.dropna().astype(int),ax=axarr[1][0])
sns.countplot(df.Rating.dropna().astype(int),ax=axarr[1][1])

sns.despine()

# %%
corr = df.corr()
#upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

#matplotlip 
f, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},annot=True)

# %%
df['Review Date'] = df['Reviews'].str[2:-2].str.split("\], \[").str[1].replace('\'', '', regex=True)

# New attribute indicating if no text reviews are available
df['Is_Reviewed'] = df['Review Date'].apply(lambda x: 0 if x == '' else 1)

# %%
from datetime import datetime as dt
from datetime import date

# Filling missing values and forming lists in the coulmn
df['Review Date'] = df['Review Date'].replace('', np.nan)
df['Review Date'] = df['Review Date'].str.split(", ")

# %%
df['Numeric ID'] = df['ID_TA'].apply(lambda id_ta: int(id_ta[1:]))

# %%
print('Loswest ID: ', df['Numeric ID'].min(), '\n',
'Highest ID: ', df['Numeric ID'].max())
# Out:
# Loswest ID:  680315
#  Highest ID:  13555245

# %%
plt.xlabel('Numeric ID')
plt.ylabel('Count')
plt.title('Empty \'Reviews\'')
df[df['Review Date'].isna()]['Numeric ID'].hist(bins=100, range=(500000, 14000000))

# %%
df.sample(5)
# Out:
#        Restaurant_id                Name        City  \
# 4796            1362               Kabar      Athens
# 31516           1655            Pizzadog      Dublin
# 28669            917            Munchies  Copenhagen
# 62986          17406  Baxter's Brasserie      London
# 26591           1445              Bistro    Budapest
#
#                                        Cuisine_Style  Ranking  Rating  \
# 4796                                     ['Unknown']   1364.0     4.5
# 31516                         ['Fast Food', 'Pizza']   1659.0     3.5
# 28669                                   ['American']    918.0     5.0
# 62986                                     ['French']      NaN     NaN
# 26591  ['European', 'Hungarian', 'Central European']   1446.0     3.5
#
#        Number of Reviews                                            Reviews  \
# 4796                 3.0  [['Good choice for Greek food at busy Thissei....
# 31516               13.0  [['Good Pizza', 'Can not fault it. Good Value'...
# 28669                4.0  [['AMAZING!', 'Delicious Ice Cream'], ['12/29/...
# 62986                NaN                                                NaN
# 26591               20.0  [['Nostalgic but not cheap...', 'Slightly over...
#
#                                                   URL_TA      ID_TA  \
# 4796   /Restaurant_Review-g189400-d7988636-Reviews-Ka...   d7988636
# 31516  /Restaurant_Review-g186605-d5863881-Reviews-Pi...   d5863881
# 28669  /Restaurant_Review-g189541-d12988557-Reviews-M...  d12988557
# 62986  /Restaurant_Review-g186338-d5816783-Reviews-Ba...   d5816783
# 26591  /Restaurant_Review-g274887-d10744278-Reviews-B...  d10744278
#
#        Cuisine Style Was NAN  Cuisine_Qtty   Pricing  Price_Unknown  \
# 4796                    True             1  0.810768              1
# 31516                  False             2  0.000000              0
# 28669                  False             1  0.000000              0
# 62986                  False             1  0.810768              1
# 26591                  False             3  1.000000              0
#
#                     Review Date  Is_Reviewed  Numeric ID
# 4796   [08/29/2015, 04/18/2015]            1     7988636
# 31516  [07/17/2017, 12/20/2016]            1     5863881
# 28669  [12/29/2017, 11/18/2017]            1    12988557
# 62986                       NaN            1     5816783
# 26591  [11/14/2017, 10/08/2017]            1    10744278

# %%
print(df['City'].value_counts()) 
print(df['City'].nunique())
# Out:
# London        18212
# Paris         14874
# Madrid         9543
# Barcelona      8425
# Berlin         7078
# Milan          6687
# Rome           5949
# Prague         4859
# Lisbon         3986
# Vienna         3724
# Amsterdam      3434
# Brussels       3204
# Hamburg        3131
# Munich         2995
# Lyon           2930
# Stockholm      2705
# Budapest       2606
# Warsaw         2352
# Copenhagen     2109
# Dublin         2082
# Athens         1938
# Edinburgh      1865
# Zurich         1667
# Oporto         1580
# Geneva         1572
# Krakow         1354
# Helsinki       1228
# Oslo           1213
# Bratislava     1067
# Luxembourg      657
# Ljubljana       501
# Name: City, dtype: int64
# 31

# %%
rest_count = df.groupby('City')['Restaurant_id'].count().to_dict()
df['Restaurants in City'] = df['City'].map(rest_count)

# %%
df['City ranking'] = df['Ranking'] / df['Restaurants in City']

# %%
styles = df['Cuisine_Style'].str[2:-2].str.split("', '").apply(lambda x: pd.Series([1] * len(x), index=x)).fillna(0, downcast='infer')
df = df.join(styles)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125527 entries, 0 to 125526
# Data columns (total 147 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Restaurant_id          int64
#  1   Name                   object
#  2   City                   object
#  3   Cuisine_Style          object
#  4   Ranking                float64
#  5   Rating                 float64
#  6   Number of Reviews      float64
#  7   Reviews                object
#  8   URL_TA                 object
#  9   ID_TA                  object
#  10  Cuisine Style Was NAN  bool
#  11  Cuisine_Qtty           int64
#  12  Pricing                float64
#  13  Price_Unknown          int32
#  14  Review Date            object
#  15  Is_Reviewed            int64
#  16  Numeric ID             int64
#  17  Restaurants in City    int64
#  18  City ranking           float64
#  19  French                 int64
#  20  Dutch                  int64
#  21  European               int64
#  22  Vegetarian Friendly    int64
#  23  Gluten Free Options    int64
#  24  Mediterranean          int64
#  25  International          int64
#  26  Vegan Options          int64
#  27  Contemporary           int64
#  28  Asian                  int64
#  29  Indonesian             int64
#  30  Japanese               int64
#  31  Seafood                int64
#  32  Fast Food              int64
#  33  American               int64
#  34  Bar                    int64
#  35  Central European       int64
#  36  Pub                    int64
#  37  Cafe                   int64
#  38  British                int64
#  39  Healthy                int64
#  40  Indian                 int64
#  41  Tibetan                int64
#  42  Nepali                 int64
#  43  Italian                int64
#  44  Barbecue               int64
#  45  Steakhouse             int64
#  46  Latin                  int64
#  47  Argentinean            int64
#  48  South American         int64
#  49  Grill                  int64
#  50  Delicatessen           int64
#  51  Pizza                  int64
#  52  Thai                   int64
#  53  Soups                  int64
#  54  Street Food            int64
#  55  Diner                  int64
#  56  Lebanese               int64
#  57  Middle Eastern         int64
#  58  Israeli                int64
#  59  New Zealand            int64
#  60  Chinese                int64
#  61  Belgian                int64
#  62  Sushi                  int64
#  63  Spanish                int64
#  64  Korean                 int64
#  65  Turkish                int64
#  66  Vietnamese             int64
#  67  Irish                  int64
#  68  German                 int64
#  69  Halal                  int64
#  70  Gastropub              int64
#  71  Swiss                  int64
#  72  Scandinavian           int64
#  73  Unknown                int64
#  74  Fusion                 int64
#  75  Arabic                 int64
#  76  Balti                  int64
#  77  Moroccan               int64
#  78  Tunisian               int64
#  79  Persian                int64
#  80  Wine Bar               int64
#  81  Portuguese             int64
#  82  Mexican                int64
#  83  Central American       int64
#  84  Australian             int64
#  85  Eastern European       int64
#  86  Greek                  int64
#  87  Caribbean              int64
#  88  African                int64
#  89  Ethiopian              int64
#  90  Brew Pub               int64
#  91  Southwestern           int64
#  92  Singaporean            int64
#  93  Malaysian              int64
#  94  Minority Chinese       int64
#  95  Peruvian               int64
#  96  Taiwanese              int64
#  97  Hawaiian               int64
#  98  Jamaican               int64
#  99  Kosher                 int64
#  100 Brazilian              int64
#  101 Pakistani              int64
#  102 Swedish                int64
#  103 Norwegian              int64
#  104 Afghani                int64
#  105 Colombian              int64
#  106 Ecuadorean             int64
#  107 Austrian               int64
#  108 Danish                 int64
#  109 Romanian               int64
#  110 Cajun & Creole         int64
#  111 Georgian               int64
#  112 Egyptian               int64
#  113 Central Asian          int64
#  114 Cuban                  int64
#  115 Russian                int64
#  116 Fujian                 int64
#  117 Czech                  int64
#  118 Armenian               int64
#  119 Venezuelan             int64
#  120 Bangladeshi            int64
#  121 Scottish               int64
#  122 Azerbaijani            int64
#  123 Polynesian             int64
#  124 Albanian               int64
#  125 Hungarian              int64
#  126 Filipino               int64
#  127 Croatian               int64
#  128 Polish                 int64
#  129 Yunnan                 int64
#  130 Cambodian              int64
#  131 Chilean                int64
#  132 Mongolian              int64
#  133 Uzbek                  int64
#  134 Xinjiang               int64
#  135 Ukrainian              int64
#  136 Sri Lankan             int64
#  137 Caucasian              int64
#  138 Latvian                int64
#  139 Salvadoran             int64
#  140 Guatemalan             int64
#  141 Native American        int64
#  142 Canadian               int64
#  143 Slovenian              int64
#  144 Burmese                int64
#  145 Puerto Rican           int64
#  146 Welsh                  int64
# dtypes: bool(1), float64(5), int32(1), int64(133), object(7)
# memory usage: 139.5+ MB

# %%
df.sample(10)
# Out:
#         Restaurant_id                Name        City  \
# 111952           2822            Delponte        Rome
# 103513          14116              Sadoud       Paris
# 111763           2633          Ippo pizza        Rome
# 95748            6351             Chez DO       Paris
# 40384             645   Kawiarnia Bankowa      Krakow
# 92075            2678    Le Petit Suffren       Paris
# 122873           1365  Boscaiola pizzeria      Warsaw
# 64416             624              Wu Xia  Luxembourg
# 50828            5248  Sushi Bar Atari-Ya      London
# 16333            2536       Cafe Seeblick      Berlin
#
#                                             Cuisine_Style  Ranking  Rating  \
# 111952     ['Italian', 'Bar', 'Delicatessen', 'Wine Bar']   2823.0     5.0
# 103513                                        ['Unknown']      NaN     NaN
# 111763                   ['Pizza', 'Vegetarian Friendly']   2634.0     4.0
# 95748                                         ['Unknown']   6352.0     4.5
# 40384   ['Polish', 'Bar', 'European', 'Eastern Europea...    646.0     3.5
# 92075   ['French', 'European', 'American', 'Pub', 'Veg...   2679.0     4.0
# 122873                                        ['Italian']   1367.0     3.5
# 64416                                           ['Asian']      NaN     NaN
# 50828   ['Japanese', 'Sushi', 'Asian', 'Gluten Free Op...   5257.0     4.0
# 16333          ['German', 'European', 'Central European']   2538.0     4.0
#
#         Number of Reviews                                            Reviews  \
# 111952               25.0  [['Fantastic', 'Exceptional milk!'], ['11/10/2...
# 103513                NaN                                                NaN
# 111763              229.0  [['Great Pizzeria', 'Excellent pizzas of authe...
# 95748                17.0  [['Local gem', 'Quick meal'], ['10/24/2017', '...
# 40384                54.0  [['Lovely spot in main square.', 'More than yo...
# 92075                57.0  [['A perfect petit dejeuner...', 'Nice Cafe, G...
# 122873               11.0  [['Good place, close to the Copernicus Scienc....
# 64416                 NaN                                                NaN
# 50828                86.0  [['Great sushi and sashimi', 'good food, high ...
# 16333                30.0  [['Good Neighbourhood Nosh', 'Mediocrity from ...
#
#                                                    URL_TA      ID_TA  ...  \
# 111952  /Restaurant_Review-g187791-d8822376-Reviews-De...   d8822376  ...
# 103513  /Restaurant_Review-g187147-d1332650-Reviews-Sa...   d1332650  ...
# 111763  /Restaurant_Review-g187791-d4971877-Reviews-Ip...   d4971877  ...
# 95748   /Restaurant_Review-g187147-d811271-Reviews-Che...    d811271  ...
# 40384   /Restaurant_Review-g274772-d7929760-Reviews-Ka...   d7929760  ...
# 92075   /Restaurant_Review-g187147-d11956755-Reviews-L...  d11956755  ...
# 122873  /Restaurant_Review-g274856-d11694120-Reviews-B...  d11694120  ...
# 64416   /Restaurant_Review-g190356-d743777-Reviews-Wu_...    d743777  ...
# 50828   /Restaurant_Review-g186338-d3370538-Reviews-Su...   d3370538  ...
# 16333   /Restaurant_Review-g187323-d1341758-Reviews-Ca...   d1341758  ...
#
#         Caucasian  Latvian  Salvadoran  Guatemalan Native American  Canadian  \
# 111952          0        0           0           0               0         0
# 103513          0        0           0           0               0         0
# 111763          0        0           0           0               0         0
# 95748           0        0           0           0               0         0
# 40384           0        0           0           0               0         0
# 92075           0        0           0           0               0         0
# 122873          0        0           0           0               0         0
# 64416           0        0           0           0               0         0
# 50828           0        0           0           0               0         0
# 16333           0        0           0           0               0         0
#
#         Slovenian  Burmese  Puerto Rican  Welsh
# 111952          0        0             0      0
# 103513          0        0             0      0
# 111763          0        0             0      0
# 95748           0        0             0      0
# 40384           0        0             0      0
# 92075           0        0             0      0
# 122873          0        0             0      0
# 64416           0        0             0      0
# 50828           0        0             0      0
# 16333           0        0             0      0
#
# [10 rows x 147 columns]

# %%
object_columns = [c for c in df.columns if df[c].dtypes == 'object']
numeric_columns = [c for c in df.columns if df[c].dtypes != 'object']

sum(df[numeric_columns].isna().sum().to_list())
# Out:
# 46276

# %%
df.drop(object_columns, axis = 1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.25)

# %%
y = train.Rating.values            # target
X = train.drop(['Rating'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=40)

# %%
model = RandomForestRegressor(n_estimators=100, verbose=1, n_jobs=-1, random_state=40)

# %%
sum(df[numeric_columns].isna().sum().to_list())
# Out:
# 0

# %%
model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   12.3s finished
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=40, verbose=1, warm_start=False)

# %%
def rating_round(x, base=0.5):
    return base * round(x/base)

def predict(ds):
    return np.array([rating_round(x) for x in model.predict(ds)])

y_pred = predict(X_test)
# Out:
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.18346565412495686

# %%
plt.rcParams['figure.figsize'] = (10,10)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')

# %%
test = test.drop(['Rating'], axis=1)

# %%
predict_submission = predict(test)
# Out:
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
submission = pd.read_csv('F:\Machine Learning Project\RestaurantRatings\RestaurantRatings\submission.csv')
submission['Rating'] = predict_submission
submission.to_csv('submission.csv', index=False)
submission.head(10)
# Out:
#   Restaurant_id  Rating
# 0           NaN     4.5
# 1           NaN     4.0
# 2           NaN     4.5
# 3           NaN     4.0
# 4           NaN     3.0
# 5           NaN     4.5
# 6           NaN     4.5
# 7           NaN     4.0
# 8           NaN     4.5
# 9           NaN     4.0

# %%
submission
# Out:
#       Restaurant_id  Rating
# 0               NaN     4.5
# 1               NaN     4.0
# 2               NaN     4.5
# 3               NaN     4.0
# 4               NaN     3.0
# ...             ...     ...
# 27034           NaN     3.5
# 27035           NaN     3.0
# 27036           NaN     3.5
# 27037           NaN     3.0
# 27038           NaN     3.5
#
# [27039 rows x 2 columns]

# %%
test
# Out:
#         Restaurant_id  Ranking  Number of Reviews  Cuisine Style Was NAN  \
# 7519             2147   2148.0               39.0                  False
# 50393            4813   4822.0              187.0                  False
# 112727           3597   3598.0               19.0                  False
# 112770           3640   3641.0               60.0                  False
# 74115            6736   6739.0               63.0                  False
# ...               ...      ...                ...                    ...
# 114694           5564   5566.0               74.0                  False
# 60904           15324  15336.0               53.0                  False
# 73987            6608   6611.0               28.0                   True
# 102039          12642  12644.0                2.0                  False
# 110275           1145   1146.0             1146.0                  False
#
#         Cuisine_Qtty   Pricing  Price_Unknown  Is_Reviewed  Numeric ID  \
# 7519               7  1.000000              0            1     7214585
# 50393              5  1.000000              0            1      731179
# 112727             1  1.000000              0            0    12437767
# 112770             1  0.000000              0            1     6028026
# 74115              1  1.000000              0            1     7284929
# ...              ...       ...            ...          ...         ...
# 114694             1  0.000000              0            1     7333785
# 60904              2  1.000000              0            1    10393124
# 73987              1  0.810768              1            1     9743193
# 102039             1  0.810768              1            0     4364384
# 110275             6  1.000000              0            1     1189492
#
#         Restaurants in City  ...  Caucasian  Latvian  Salvadoran  Guatemalan  \
# 7519                   8425  ...          0        0           0           0
# 50393                 18212  ...          0        0           0           0
# 112727                 5949  ...          0        0           0           0
# 112770                 5949  ...          0        0           0           0
# 74115                  9543  ...          0        0           0           0
# ...                     ...  ...        ...      ...         ...         ...
# 114694                 5949  ...          0        0           0           0
# 60904                 18212  ...          0        0           0           0
# 73987                  9543  ...          0        0           0           0
# 102039                14874  ...          0        0           0           0
# 110275                 5949  ...          0        0           0           0
#
#         Native American  Canadian  Slovenian  Burmese  Puerto Rican  Welsh
# 7519                  0         0          0        0             0      0
# 50393                 0         0          0        0             0      0
# 112727                0         0          0        0             0      0
# 112770                0         0          0        0             0      0
# 74115                 0         0          0        0             0      0
# ...                 ...       ...        ...      ...           ...    ...
# 114694                0         0          0        0             0      0
# 60904                 0         0          0        0             0      0
# 73987                 0         0          0        0             0      0
# 102039                0         0          0        0             0      0
# 110275                0         0          0        0             0      0
#
# [27039 rows x 139 columns]
